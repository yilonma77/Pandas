# %% [markdown]
# # 📈 Analyse Complète des Actions Micron Technology (MU)
#
# Cette analyse approfondie explore les données historiques de Micron Technology, un leader dans la fabrication de mémoires et de stockage.
#
# ## 🎯 Objectifs de l'analyse
# - Analyse technique avec indicateurs avancés
# - Visualisations interactives et stylées
# - Évaluation de la performance et des tendances
# - Analyse des volumes et de la volatilité
# - Modélisation prédictive

# %%
# Import des bibliothèques essentielles
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import warnings
from datetime import datetime, timedelta
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Configuration des styles
warnings.filterwarnings('ignore')
plt.style.use('dark_background')
sns.set_palette("husl")

# Configuration Plotly pour thème sombre
import plotly.io as pio
pio.templates.default = "plotly_dark"

# Configuration des paramètres d'affichage
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

print("✅ Toutes les bibliothèques importées avec succès!")
print("🎨 Thème sombre activé pour les visualisations")
# Out:
# /Users/grtk/opt/anaconda3/envs/py313/lib/python3.13/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# ✅ Toutes les bibliothèques importées avec succès!
# 🎨 Thème sombre activé pour les visualisations

# %% [markdown]
# ## 📊 1. Récupération et Exploration des Données

# %%
# Récupération des données de Micron Technology (MU)
ticker = "MU"
stock = yf.Ticker(ticker)

# Récupération de 5 ans de données historiques
end_date = datetime.now()
start_date = end_date - timedelta(days=5*365)

print(f"📈 Récupération des données pour {ticker} de {start_date.strftime('%Y-%m-%d')} à {end_date.strftime('%Y-%m-%d')}")
data = stock.history(start=start_date, end=end_date)

# Informations générales sur l'entreprise
info = stock.info
print(f"\n🏢 Informations sur {info.get('longName', 'Micron Technology')}")
print(f"💼 Secteur: {info.get('sector', 'N/A')}")
print(f"🏭 Industrie: {info.get('industry', 'N/A')}")
print(f"💰 Capitalisation: ${info.get('marketCap', 0):,}")
print(f"👥 Employés: {info.get('fullTimeEmployees', 'N/A'):,}")

# Aperçu des données
print(f"\n📊 Données récupérées: {len(data)} jours")
print(f"📅 Période: {data.index[0].strftime('%Y-%m-%d')} → {data.index[-1].strftime('%Y-%m-%d')}")
print("\n🔍 Aperçu des données:")
display(data.head())

print("\n📈 Statistiques descriptives:")
display(data.describe())
# Out:
# 📈 Récupération des données pour MU de 2021-02-15 à 2026-02-14
#
# 🏢 Informations sur Micron Technology, Inc.
# 💼 Secteur: Technology
# 🏭 Industrie: Semiconductors
# 💰 Capitalisation: $463,327,133,696
# 👥 Employés: 53,000
#
# 📊 Données récupérées: 1256 jours
# 📅 Période: 2021-02-16 → 2026-02-13
#
# 🔍 Aperçu des données:
#                                 Open       High        Low      Close  \
# Date
# 2021-02-16 00:00:00-05:00  87.051678  87.051678  84.934417  85.607643
# 2021-02-17 00:00:00-05:00  84.583163  85.197849  82.836664  83.958717
# 2021-02-18 00:00:00-05:00  84.417295  86.573591  83.870907  86.388206
# 2021-02-19 00:00:00-05:00  88.056631  89.266492  86.651625  88.749374
# 2021-02-22 00:00:00-05:00  87.354135  88.320073  83.831869  84.183121
#
#                              Volume  Dividends  Stock Splits
# Date
# 2021-02-16 00:00:00-05:00  10312800        0.0           0.0
# 2021-02-17 00:00:00-05:00  10033500        0.0           0.0
# ...

# %% [markdown]
# ## 🔧 2. Calcul des Indicateurs Techniques

# %%
# Calcul des indicateurs techniques
df = data.copy()

# Moyennes mobiles
df['MA_20'] = df['Close'].rolling(window=20).mean()
df['MA_50'] = df['Close'].rolling(window=50).mean()
df['MA_200'] = df['Close'].rolling(window=200).mean()

# Moyennes mobiles exponentielles
df['EMA_12'] = df['Close'].ewm(span=12).mean()
df['EMA_26'] = df['Close'].ewm(span=26).mean()

# MACD (Moving Average Convergence Divergence)
df['MACD'] = df['EMA_12'] - df['EMA_26']
df['MACD_Signal'] = df['MACD'].ewm(span=9).mean()
df['MACD_Histogram'] = df['MACD'] - df['MACD_Signal']

# RSI (Relative Strength Index)
def calculate_rsi(prices, window=14):
    delta = prices.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

df['RSI'] = calculate_rsi(df['Close'])

# Bollinger Bands
window = 20
df['BB_Middle'] = df['Close'].rolling(window=window).mean()
df['BB_Std'] = df['Close'].rolling(window=window).std()
df['BB_Upper'] = df['BB_Middle'] + (df['BB_Std'] * 2)
df['BB_Lower'] = df['BB_Middle'] - (df['BB_Std'] * 2)

# Volatilité (écart-type mobile sur 20 jours)
df['Volatility'] = df['Close'].pct_change().rolling(window=20).std() * np.sqrt(252) * 100

# Volume weighted average price (VWAP)
df['VWAP'] = (df['Close'] * df['Volume']).cumsum() / df['Volume'].cumsum()

# Support et résistance (bas et hauts sur 20 jours)
df['Support'] = df['Low'].rolling(window=20).min()
df['Resistance'] = df['High'].rolling(window=20).max()

# Rendements
df['Daily_Return'] = df['Close'].pct_change()
df['Cumulative_Return'] = (1 + df['Daily_Return']).cumprod() - 1

print("✅ Indicateurs techniques calculés:")
print(f"📊 Moyennes Mobiles: MA20, MA50, MA200")
print(f"📈 MACD et Signal")
print(f"⚡ RSI (14 jours)")
print(f"📉 Bandes de Bollinger")
print(f"💨 Volatilité annualisée")
print(f"💰 VWAP")
print(f"🎯 Support/Résistance")

# Aperçu des nouveaux indicateurs
print(f"\n🔍 Dernières valeurs des indicateurs:")
latest = df.iloc[-1]
print(f"💲 Prix de clôture: ${latest['Close']:.2f}")
print(f"📊 MA20: ${latest['MA_20']:.2f}")
print(f"📊 MA50: ${latest['MA_50']:.2f}")
print(f"⚡ RSI: {latest['RSI']:.2f}")
print(f"📈 MACD: {latest['MACD']:.4f}")
print(f"💨 Volatilité: {latest['Volatility']:.2f}%")
# Out:
# ✅ Indicateurs techniques calculés:
# 📊 Moyennes Mobiles: MA20, MA50, MA200
# 📈 MACD et Signal
# ⚡ RSI (14 jours)
# 📉 Bandes de Bollinger
# 💨 Volatilité annualisée
# 💰 VWAP
# 🎯 Support/Résistance
#
# 🔍 Dernières valeurs des indicateurs:
# 💲 Prix de clôture: $411.66
# 📊 MA20: $400.32
# 📊 MA50: $330.17
# ⚡ RSI: 54.93
# 📈 MACD: 19.7671
# 💨 Volatilité: 76.87%

# %% [markdown]
# ## 🎨 3. Visualisations Avancées

# %%
# Graphique principal: Prix et Moyennes Mobiles
fig = make_subplots(
    rows=4, cols=1,
    subplot_titles=('Prix et Moyennes Mobiles', 'Volume', 'MACD', 'RSI'),
    vertical_spacing=0.05,
    row_heights=[0.5, 0.2, 0.15, 0.15]
)

# Prix et moyennes mobiles
fig.add_trace(
    go.Scatter(x=df.index, y=df['Close'], name='Prix de clôture', 
               line=dict(color='#00ff9f', width=2)),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(x=df.index, y=df['MA_20'], name='MA 20',
               line=dict(color='#ffa500', width=1.5)),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(x=df.index, y=df['MA_50'], name='MA 50',
               line=dict(color='#ff6b6b', width=1.5)),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(x=df.index, y=df['MA_200'], name='MA 200',
               line=dict(color='#4ecdc4', width=2)),
    row=1, col=1
)

# Bandes de Bollinger
fig.add_trace(
    go.Scatter(x=df.index, y=df['BB_Upper'], 
               line=dict(color='rgba(255,255,255,0.3)', width=1),
               name='BB Supérieure', showlegend=False),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(x=df.index, y=df['BB_Lower'], 
               fill='tonexty', fillcolor='rgba(255,255,255,0.1)',
               line=dict(color='rgba(255,255,255,0.3)', width=1),
               name='Zone Bollinger', showlegend=True),
    row=1, col=1
)

# Volume
colors = ['#ff4757' if df['Close'].iloc[i] < df['Open'].iloc[i] 
          else '#2ed573' for i in range(len(df))]

fig.add_trace(
    go.Bar(x=df.index, y=df['Volume'], name='Volume',
           marker_color=colors, opacity=0.6),
    row=2, col=1
)

# MACD
fig.add_trace(
    go.Scatter(x=df.index, y=df['MACD'], name='MACD',
               line=dict(color='#3742fa', width=2)),
    row=3, col=1
)

fig.add_trace(
    go.Scatter(x=df.index, y=df['MACD_Signal'], name='Signal',
               line=dict(color='#ff6348', width=1.5)),
    row=3, col=1
)

# Histogramme MACD
hist_colors = ['#2ed573' if x >= 0 else '#ff4757' for x in df['MACD_Histogram']]
fig.add_trace(
    go.Bar(x=df.index, y=df['MACD_Histogram'], name='Histogramme',
           marker_color=hist_colors, opacity=0.6),
    row=3, col=1
)

# RSI
fig.add_trace(
    go.Scatter(x=df.index, y=df['RSI'], name='RSI',
               line=dict(color='#ffa502', width=2)),
    row=4, col=1
)

# Lignes de référence RSI
fig.add_hline(y=70, line_dash="dash", line_color="rgba(255,255,255,0.5)", 
              row=4, col=1)
fig.add_hline(y=30, line_dash="dash", line_color="rgba(255,255,255,0.5)", 
              row=4, col=1)

# Configuration du layout
fig.update_layout(
    title=dict(
        text=f'<b>Analyse Technique Complète - {ticker}</b>',
        x=0.5,
        font=dict(size=24, color='white')
    ),
    template='plotly_dark',
    height=1200,
    showlegend=True,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    )
)

fig.update_xaxes(showgrid=True, gridcolor='rgba(255,255,255,0.1)')
fig.update_yaxes(showgrid=True, gridcolor='rgba(255,255,255,0.1)')

fig.show()

print("📊 Graphique principal créé avec succès!")
# Out:
# 📊 Graphique principal créé avec succès!

# %%
# Analyse de la volatilité et des rendements
fig_vol = make_subplots(
    rows=2, cols=2,
    subplot_titles=('Volatilité dans le temps', 'Distribution des rendements quotidiens',
                   'Rendements cumulatifs', 'Corrélation Volume-Prix'),
    specs=[[{"secondary_y": True}, {"type": "histogram"}],
           [{"colspan": 1}, {"type": "scatter"}]]
)

# Volatilité
fig_vol.add_trace(
    go.Scatter(x=df.index, y=df['Volatility'], name='Volatilité (%)',
               line=dict(color='#ff6b6b', width=2)),
    row=1, col=1
)

# Prix sur axe secondaire
fig_vol.add_trace(
    go.Scatter(x=df.index, y=df['Close'], name='Prix',
               line=dict(color='#4ecdc4', width=1, dash='dot')),
    row=1, col=1, secondary_y=True
)

# Distribution des rendements
fig_vol.add_trace(
    go.Histogram(x=df['Daily_Return'].dropna()*100, nbinsx=50,
                name='Rendements (%)', marker_color='#45aaf2',
                opacity=0.7),
    row=1, col=2
)

# Rendements cumulatifs
fig_vol.add_trace(
    go.Scatter(x=df.index, y=df['Cumulative_Return']*100, 
               name='Rendement Cumulatif (%)',
               line=dict(color='#26de81', width=3),
               fill='tozeroy', fillcolor='rgba(38, 222, 129, 0.1)'),
    row=2, col=1
)

# Corrélation Volume-Prix (rendements)
price_change = df['Daily_Return'].dropna()
volume_change = df['Volume'].pct_change().dropna()

# Synchroniser les longueurs
min_len = min(len(price_change), len(volume_change))
price_change = price_change[-min_len:]
volume_change = volume_change[-min_len:]

fig_vol.add_trace(
    go.Scatter(x=volume_change*100, y=price_change*100,
               mode='markers', name='Vol vs Prix',
               marker=dict(color='#fd79a8', size=4, opacity=0.6)),
    row=2, col=2
)

# Configuration des axes
fig_vol.update_xaxes(title_text="Date", row=1, col=1)
fig_vol.update_yaxes(title_text="Volatilité (%)", row=1, col=1)
fig_vol.update_yaxes(title_text="Prix ($)", row=1, col=1, secondary_y=True)

fig_vol.update_xaxes(title_text="Rendement quotidien (%)", row=1, col=2)
fig_vol.update_yaxes(title_text="Fréquence", row=1, col=2)

fig_vol.update_xaxes(title_text="Date", row=2, col=1)
fig_vol.update_yaxes(title_text="Rendement Cumulatif (%)", row=2, col=1)

fig_vol.update_xaxes(title_text="Variation Volume (%)", row=2, col=2)
fig_vol.update_yaxes(title_text="Rendement Prix (%)", row=2, col=2)

fig_vol.update_layout(
    title=dict(
        text=f'<b>Analyse de la Volatilité et des Rendements - {ticker}</b>',
        x=0.5,
        font=dict(size=20, color='white')
    ),
    template='plotly_dark',
    height=800,
    showlegend=True
)

fig_vol.show()

# Statistiques sur les rendements
returns_stats = df['Daily_Return'].describe()
print("📊 Statistiques des rendements quotidiens:")
print(f"📈 Rendement moyen: {returns_stats['mean']*100:.3f}%")
print(f"📊 Médiane: {returns_stats['50%']*100:.3f}%")
print(f"💨 Écart-type: {returns_stats['std']*100:.3f}%")
print(f"📉 Min: {returns_stats['min']*100:.2f}%")
print(f"📈 Max: {returns_stats['max']*100:.2f}%")

# Ratio de Sharpe (approximatif, sans taux sans risque)
sharpe_ratio = (df['Daily_Return'].mean() / df['Daily_Return'].std()) * np.sqrt(252)
print(f"\n⚡ Ratio de Sharpe annualisé: {sharpe_ratio:.3f}")

# Volatilité actuelle vs moyenne
current_vol = df['Volatility'].iloc[-1]
avg_vol = df['Volatility'].mean()
print(f"\n💨 Volatilité actuelle: {current_vol:.2f}%")
print(f"💨 Volatilité moyenne: {avg_vol:.2f}%")
vol_status = "✅ FAIBLE" if current_vol < avg_vol else "⚠️ ÉLEVÉE"
print(f"📊 Status: {vol_status}")
# Out:
# 📊 Statistiques des rendements quotidiens:
# 📈 Rendement moyen: 0.174%
# 📊 Médiane: 0.105%
# 💨 Écart-type: 3.120%
# 📉 Min: -16.18%
# 📈 Max: 18.81%
#
# ⚡ Ratio de Sharpe annualisé: 0.884
#
# 💨 Volatilité actuelle: 76.87%
# 💨 Volatilité moyenne: 46.33%
# 📊 Status: ⚠️ ÉLEVÉE

# %%
# Analyse des niveaux de support et résistance
fig_sr = go.Figure()

# Données des 6 derniers mois pour une meilleure lisibilité
recent_data = df.last('6M').copy()

# Prix principal
fig_sr.add_trace(go.Candlestick(
    x=recent_data.index,
    open=recent_data['Open'],
    high=recent_data['High'],
    low=recent_data['Low'],
    close=recent_data['Close'],
    name='Prix',
    increasing_line_color='#26de81',
    decreasing_line_color='#ff4757'
))

# Support et résistance
fig_sr.add_trace(go.Scatter(
    x=recent_data.index, y=recent_data['Support'],
    name='Support', line=dict(color='#ff6b6b', width=2, dash='dash'),
    fill=None
))

fig_sr.add_trace(go.Scatter(
    x=recent_data.index, y=recent_data['Resistance'],
    name='Résistance', line=dict(color='#4ecdc4', width=2, dash='dash'),
    fill='tonexty', fillcolor='rgba(255, 107, 107, 0.1)'
))

# VWAP
fig_sr.add_trace(go.Scatter(
    x=recent_data.index, y=recent_data['VWAP'],
    name='VWAP', line=dict(color='#ffa502', width=2)
))

# Moyennes mobiles importantes
fig_sr.add_trace(go.Scatter(
    x=recent_data.index, y=recent_data['MA_20'],
    name='MA 20', line=dict(color='#fd79a8', width=1.5)
))

fig_sr.add_trace(go.Scatter(
    x=recent_data.index, y=recent_data['MA_50'],
    name='MA 50', line=dict(color='#45aaf2', width=1.5)
))

# Configuration
fig_sr.update_layout(
    title=dict(
        text=f'<b>Analyse Support/Résistance - {ticker} (6 derniers mois)</b>',
        x=0.5,
        font=dict(size=20, color='white')
    ),
    template='plotly_dark',
    height=600,
    xaxis_rangeslider_visible=False,
    showlegend=True
)

fig_sr.show()

# Analyse des niveaux clés
current_price = recent_data['Close'].iloc[-1]
current_support = recent_data['Support'].iloc[-1]
current_resistance = recent_data['Resistance'].iloc[-1]
current_vwap = recent_data['VWAP'].iloc[-1]

print("🎯 Niveaux techniques actuels:")
print(f"💲 Prix actuel: ${current_price:.2f}")
print(f"🔻 Support: ${current_support:.2f}")
print(f"🔺 Résistance: ${current_resistance:.2f}")
print(f"💰 VWAP: ${current_vwap:.2f}")

# Distance aux niveaux clés
support_distance = ((current_price - current_support) / current_price) * 100
resistance_distance = ((current_resistance - current_price) / current_price) * 100
vwap_position = "au-dessus" if current_price > current_vwap else "en-dessous"

print(f"\n📊 Analyse de position:")
print(f"🔻 Distance au support: {support_distance:.1f}%")
print(f"🔺 Distance à la résistance: {resistance_distance:.1f}%")
print(f"💰 Position vs VWAP: {vwap_position}")
# Out:
# 🎯 Niveaux techniques actuels:
# 💲 Prix actuel: $411.66
# 🔻 Support: $352.04
# 🔺 Résistance: $455.50
# 💰 VWAP: $108.48
#
# 📊 Analyse de position:
# 🔻 Distance au support: 14.5%
# 🔺 Distance à la résistance: 10.6%
# 💰 Position vs VWAP: au-dessus

# %% [markdown]
# ## 🤖 4. Modélisation Prédictive

# %%
# Préparation des données pour la modélisation
def create_features(df, lookback_days=5):
    """Crée des features pour la prédiction"""
    features_df = df.copy()
    
    # Features de prix
    for i in range(1, lookback_days + 1):
        features_df[f'Close_lag_{i}'] = features_df['Close'].shift(i)
        features_df[f'Volume_lag_{i}'] = features_df['Volume'].shift(i)
        features_df[f'Return_lag_{i}'] = features_df['Daily_Return'].shift(i)
    
    # Features techniques
    features_df['Price_MA20_ratio'] = features_df['Close'] / features_df['MA_20']
    features_df['Price_MA50_ratio'] = features_df['Close'] / features_df['MA_50']
    features_df['RSI_level'] = features_df['RSI']
    features_df['MACD_signal'] = (features_df['MACD'] > features_df['MACD_Signal']).astype(int)
    features_df['BB_position'] = (features_df['Close'] - features_df['BB_Lower']) / (features_df['BB_Upper'] - features_df['BB_Lower'])
    
    # Features de volatilité
    features_df['Vol_ratio'] = features_df['Volatility'] / features_df['Volatility'].mean()
    
    # Target: rendement du lendemain
    features_df['Target'] = features_df['Close'].shift(-1) / features_df['Close'] - 1
    
    return features_df

# Création du dataset
ml_data = create_features(df, lookback_days=5)

# Sélection des features
feature_columns = [col for col in ml_data.columns if 
                  ('lag_' in col or 'ratio' in col or 'level' in col or 
                   'signal' in col or 'position' in col or 'Vol_ratio' in col)]

# Nettoyage des données
ml_clean = ml_data[feature_columns + ['Target']].dropna()

print(f"📊 Dataset créé:")
print(f"🔢 Nombre d'observations: {len(ml_clean)}")
print(f"📈 Nombre de features: {len(feature_columns)}")
print(f"📅 Période: {ml_clean.index[0].strftime('%Y-%m-%d')} → {ml_clean.index[-1].strftime('%Y-%m-%d')}")

# Division train/test (80/20)
split_point = int(len(ml_clean) * 0.8)
train_data = ml_clean.iloc[:split_point]
test_data = ml_clean.iloc[split_point:]

X_train = train_data[feature_columns]
y_train = train_data['Target']
X_test = test_data[feature_columns]
y_test = test_data['Target']

print(f"\n🎯 Division des données:")
print(f"📚 Training: {len(X_train)} observations")
print(f"🧪 Test: {len(X_test)} observations")

# Modèle 1: Régression Linéaire
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
lr_pred = lr_model.predict(X_test)

# Modèle 2: Random Forest
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

# Évaluation des modèles
lr_mse = mean_squared_error(y_test, lr_pred)
lr_r2 = r2_score(y_test, lr_pred)

rf_mse = mean_squared_error(y_test, rf_pred)
rf_r2 = r2_score(y_test, rf_pred)

print(f"\n🤖 Performance des modèles:")
print(f"📊 Régression Linéaire:")
print(f"   - MSE: {lr_mse:.6f}")
print(f"   - R²: {lr_r2:.4f}")

print(f"🌳 Random Forest:")
print(f"   - MSE: {rf_mse:.6f}")
print(f"   - R²: {rf_r2:.4f}")

best_model = "Random Forest" if rf_r2 > lr_r2 else "Régression Linéaire"
print(f"\n🏆 Meilleur modèle: {best_model}")

# Feature importance (Random Forest)
feature_importance = pd.DataFrame({
    'feature': feature_columns,
    'importance': rf_model.feature_importances_
}).sort_values('importance', ascending=False)

print(f"\n🔍 Top 10 features importantes:")
for i, (idx, row) in enumerate(feature_importance.head(10).iterrows()):
    print(f"{i+1:2d}. {row['feature']:20s}: {row['importance']:.4f}")
# Out:
# 📊 Dataset créé:
# 🔢 Nombre d'observations: 1206
# 📈 Nombre de features: 21
# 📅 Période: 2021-04-27 → 2026-02-12
#
# 🎯 Division des données:
# 📚 Training: 964 observations
# 🧪 Test: 242 observations
#
# 🤖 Performance des modèles:
# 📊 Régression Linéaire:
#    - MSE: 0.001866
#    - R²: -0.1508
# 🌳 Random Forest:
#    - MSE: 0.002038
#    - R²: -0.2571
#
# 🏆 Meilleur modèle: Régression Linéaire
#
# 🔍 Top 10 features importantes:
#  1. Return_lag_5        : 0.0709
#  2. Return_lag_4        : 0.0691
#  3. Vol_ratio           : 0.0685
#  4. Return_lag_1        : 0.0671
#  5. Return_lag_3        : 0.0637
#  6. Price_MA50_ratio    : 0.0610
#  7. Return_lag_2        : 0.0594
#  8. Volume_lag_3        : 0.0553
#  9. Volume_lag_2        : 0.0546
# 10. Volume_lag_4        : 0.0473

# %%
# Visualisation des prédictions
fig_pred = make_subplots(
    rows=2, cols=2,
    subplot_titles=('Prédictions vs Réel', 'Feature Importance', 
                   'Résidus du modèle', 'Distribution des prédictions'),
    specs=[[{"rowspan": 1}, {"type": "bar"}],
           [{"type": "scatter"}, {"type": "histogram"}]]
)

# Prédictions vs réel
test_dates = test_data.index
fig_pred.add_trace(
    go.Scatter(x=test_dates, y=y_test*100, name='Réel', 
               line=dict(color='#26de81', width=2)),
    row=1, col=1
)

fig_pred.add_trace(
    go.Scatter(x=test_dates, y=rf_pred*100, name='Prédit (RF)',
               line=dict(color='#ff6b6b', width=2, dash='dash')),
    row=1, col=1
)

# Feature importance
top_features = feature_importance.head(10)
fig_pred.add_trace(
    go.Bar(x=top_features['importance'], y=top_features['feature'],
           name='Importance', marker_color='#45aaf2',
           orientation='h'),
    row=1, col=2
)

# Résidus
residuals = y_test - rf_pred
fig_pred.add_trace(
    go.Scatter(x=test_dates, y=residuals*100, mode='markers',
               name='Résidus', marker=dict(color='#fd79a8', size=4)),
    row=2, col=1
)

# Distribution des prédictions
fig_pred.add_trace(
    go.Histogram(x=rf_pred*100, nbinsx=30, name='Prédictions',
                marker_color='#ffa502', opacity=0.7),
    row=2, col=2
)

# Configuration
fig_pred.update_layout(
    title=dict(
        text=f'<b>Analyse Prédictive - {ticker}</b>',
        x=0.5,
        font=dict(size=20, color='white')
    ),
    template='plotly_dark',
    height=800,
    showlegend=True
)

# Labels des axes
fig_pred.update_xaxes(title_text="Date", row=1, col=1)
fig_pred.update_yaxes(title_text="Rendement (%)", row=1, col=1)

fig_pred.update_xaxes(title_text="Importance", row=1, col=2)
fig_pred.update_yaxes(title_text="Features", row=1, col=2)

fig_pred.update_xaxes(title_text="Date", row=2, col=1)
fig_pred.update_yaxes(title_text="Résidus (%)", row=2, col=1)

fig_pred.update_xaxes(title_text="Prédiction (%)", row=2, col=2)
fig_pred.update_yaxes(title_text="Fréquence", row=2, col=2)

fig_pred.show()

# Prédiction pour les prochains jours
latest_features = ml_data[feature_columns].iloc[-1:].dropna(axis=1)
if not latest_features.empty:
    # S'assurer que les features correspondent
    common_features = [col for col in feature_columns if col in latest_features.columns]
    latest_X = latest_features[common_features]
    
    if len(latest_X.columns) > 0:
        next_day_pred = rf_model.predict(latest_X.values.reshape(1, -1))[0]
        
        print(f"\n🔮 Prédiction pour le prochain jour de trading:")
        print(f"📈 Rendement prédit: {next_day_pred*100:.2f}%")
        
        confidence_level = "FORTE" if abs(next_day_pred) > 0.02 else "MODÉRÉE" if abs(next_day_pred) > 0.01 else "FAIBLE"
        direction = "HAUSSIÈRE 📈" if next_day_pred > 0 else "BAISSIÈRE 📉"
        
        print(f"🎯 Direction: {direction}")
        print(f"🎯 Confiance: {confidence_level}")
        
        # Prix cible estimé
        current_price = df['Close'].iloc[-1]
        target_price = current_price * (1 + next_day_pred)
        print(f"💰 Prix cible estimé: ${target_price:.2f}")
    else:
        print("⚠️ Impossible de faire une prédiction - données insuffisantes")
else:
    print("⚠️ Impossible de faire une prédiction - données manquantes")
# Out:
# 🔮 Prédiction pour le prochain jour de trading:
# 📈 Rendement prédit: -1.93%
# 🎯 Direction: BAISSIÈRE 📉
# 🎯 Confiance: MODÉRÉE
# 💰 Prix cible estimé: $403.70

# %% [markdown]
# ## 🎯 5. Conclusions et Recommandations

# %%
# Rapport de synthèse final
print("="*80)
print("🎯 RAPPORT D'ANALYSE COMPLET - MICRON TECHNOLOGY (MU)")
print("="*80)

# État actuel du marché
current_price = df['Close'].iloc[-1]
current_rsi = df['RSI'].iloc[-1]
current_macd = df['MACD'].iloc[-1]
current_vol = df['Volatility'].iloc[-1]

print(f"\n📊 SITUATION ACTUELLE:")
print(f"💲 Prix: ${current_price:.2f}")
print(f"⚡ RSI: {current_rsi:.1f}", end="")
if current_rsi > 70:
    print(" (SURACHETÉ ⚠️)")
elif current_rsi < 30:
    print(" (SURVENDU ✅)")
else:
    print(" (NEUTRE)")

print(f"📈 MACD: {current_macd:.4f}", end="")
print(" (HAUSSIER ✅)" if current_macd > 0 else " (BAISSIER ⚠️)")

print(f"💨 Volatilité: {current_vol:.1f}%", end="")
avg_vol = df['Volatility'].mean()
print(" (ÉLEVÉE ⚠️)" if current_vol > avg_vol * 1.2 else " (NORMALE ✅)")

# Tendance générale
ma20 = df['MA_20'].iloc[-1]
ma50 = df['MA_50'].iloc[-1]
ma200 = df['MA_200'].iloc[-1]

print(f"\n📈 ANALYSE TENDANCIELLE:")
print(f"🟢 MA20: ${ma20:.2f}", "✅" if current_price > ma20 else "❌")
print(f"🔵 MA50: ${ma50:.2f}", "✅" if current_price > ma50 else "❌")
print(f"🟣 MA200: ${ma200:.2f}", "✅" if current_price > ma200 else "❌")

# Détermination de la tendance globale
bullish_signals = sum([
    current_price > ma20,
    current_price > ma50,
    current_price > ma200,
    current_macd > 0,
    30 <= current_rsi <= 70
])

if bullish_signals >= 4:
    trend = "🟢 HAUSSIÈRE FORTE"
elif bullish_signals >= 3:
    trend = "🟡 HAUSSIÈRE MODÉRÉE"
elif bullish_signals >= 2:
    trend = "🟠 NEUTRE"
else:
    trend = "🔴 BAISSIÈRE"

print(f"\n🎯 TENDANCE GLOBALE: {trend}")

# Performance historique
total_return = (df['Close'].iloc[-1] / df['Close'].iloc[0] - 1) * 100
annualized_return = ((df['Close'].iloc[-1] / df['Close'].iloc[0]) ** (252/len(df)) - 1) * 100
max_dd = ((df['Close'].cummax() - df['Close']) / df['Close'].cummax()).max() * 100

print(f"\n📊 PERFORMANCE HISTORIQUE:")
print(f"📈 Rendement total: {total_return:.1f}%")
print(f"📅 Rendement annualisé: {annualized_return:.1f}%")
print(f"📉 Drawdown maximum: -{max_dd:.1f}%")

# Niveaux techniques clés
support = df['Support'].iloc[-1]
resistance = df['Resistance'].iloc[-1]
support_dist = ((current_price - support) / current_price) * 100
resistance_dist = ((resistance - current_price) / current_price) * 100

print(f"\n🎯 NIVEAUX TECHNIQUES:")
print(f"🔻 Support: ${support:.2f} (-{support_dist:.1f}%)")
print(f"🔺 Résistance: ${resistance:.2f} (+{resistance_dist:.1f}%)")

# Recommandations
print(f"\n💡 RECOMMANDATIONS:")

if bullish_signals >= 4:
    print("✅ ACHAT RECOMMANDÉ")
    print("   - Tendance haussière confirmée")
    print("   - Momentum positif")
elif bullish_signals >= 3:
    print("🟡 ACHAT AVEC PRUDENCE")
    print("   - Tendance globalement positive")
    print("   - Surveiller les niveaux de résistance")
elif bullish_signals >= 2:
    print("⏸️ ATTENTE")
    print("   - Signaux mixtes")
    print("   - Attendre une direction claire")
else:
    print("❌ ÉVITER/VENDRE")
    print("   - Tendance baissière dominante")
    print("   - Risque élevé")

# Niveaux d'entrée/sortie suggérés
print(f"\n🎯 NIVEAUX STRATÉGIQUES:")
print(f"🟢 Zone d'achat: ${support:.2f} - ${support*1.02:.2f}")
print(f"🔴 Stop Loss: ${support*0.98:.2f}")
print(f"🎯 Objectif 1: ${resistance*.98:.2f}")
print(f"🎯 Objectif 2: ${resistance*1.02:.2f}")

# Risques identifiés
print(f"\n⚠️ FACTEURS DE RISQUE:")
if current_vol > avg_vol * 1.2:
    print("   - Volatilité élevée")
if current_rsi > 70:
    print("   - Conditions de surachat")
if current_price < ma200:
    print("   - Prix sous la tendance long terme")

print(f"\n🔔 SURVEILLANCE RECOMMANDÉE:")
print(f"   - Volume: Confirmer les mouvements")
print(f"   - RSI: Éviter les extrêmes")
print(f"   - MACD: Suivre les croisements")
print(f"   - Support/Résistance: Points de décision")

print("\n" + "="*80)
print("📝 Cette analyse est basée sur des données historiques.")
print("🚫 Ne constitue pas un conseil en investissement.")
print("⚠️ Toujours faire ses propres recherches avant d'investir.")
print("="*80)
# Out:
# ...
# 🎯 RAPPORT D'ANALYSE COMPLET - MICRON TECHNOLOGY (MU)
# ...
#
# 📊 SITUATION ACTUELLE:
# 💲 Prix: $411.66
# ⚡ RSI: 54.9 (NEUTRE)
# 📈 MACD: 19.7671 (HAUSSIER ✅)
# 💨 Volatilité: 76.9% (ÉLEVÉE ⚠️)
#
# 📈 ANALYSE TENDANCIELLE:
# 🟢 MA20: $400.32 ✅
# 🔵 MA50: $330.17 ✅
# 🟣 MA200: $192.57 ✅
#
# 🎯 TENDANCE GLOBALE: 🟢 HAUSSIÈRE FORTE
#
# 📊 PERFORMANCE HISTORIQUE:
# 📈 Rendement total: 380.9%
# 📅 Rendement annualisé: 37.0%
# 📉 Drawdown maximum: -57.6%
#
# 🎯 NIVEAUX TECHNIQUES:
# 🔻 Support: $352.04 (-14.5%)
# 🔺 Résistance: $455.50 (+10.6%)
#
# 💡 RECOMMANDATIONS:
# ✅ ACHAT RECOMMANDÉ
#    - Tendance haussière confirmée
#    - Momentum positif
#
# 🎯 NIVEAUX STRATÉGIQUES:
# 🟢 Zone d'achat: $352.04 - $359.08
# 🔴 Stop Loss: $345.00
# 🎯 Objectif 1: $446.39
# 🎯 Objectif 2: $464.61
#
# ⚠️ FACTEURS DE RISQUE:
#    - Volatilité élevée
#
# 🔔 SURVEILLANCE RECOMMANDÉE:
#    - Volume: Confirmer les mouvements
#    - RSI: Éviter les extrêmes
#    - MACD: Suivre les croisements
# ...
